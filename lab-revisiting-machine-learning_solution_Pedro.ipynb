# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('learningSet.csv')
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15016\3708753459.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('learningSet.csv')
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# ...

# %%
df.isna().sum()
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64

# %%
drop_list=[]
drop_list = ['ZIP','OSOURCE']

# %%
nulls_perc = pd.DataFrame(df.isna().sum()/df.shape[0])
list1 = list(nulls_perc[nulls_perc[0]>0.85].index)

drop_list1 = drop_list + list1

df = df.drop(drop_list1, axis = 1)

# %%
df.shape
# Out:
# (95412, 454)

# %%
df['GENDER'].value_counts()

def clean_gender(x):
    if 'M' in x:
        return 'M'
    elif 'F' in x:
        return 'F'
    else:
        return 'other'
    
df['GENDER'] = df['GENDER'].apply(clean_gender)
df['GENDER'].value_counts(dropna=False)
# Out:
# F        51277
# M        39094
# other     5041
# Name: GENDER, dtype: int64

# %%
df['GENDER'].isna().sum() # no missing values
# Out:
# 0
